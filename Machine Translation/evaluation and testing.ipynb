# %% [markdown]
# # **Torgo Speakers spelling correction evaluation and testing script using machine translation**

# %% [markdown]
# ### **Objective: Spelling correction evaluation and testing for Torgo dataset speakers using machine translation**

# %% [markdown]
# ### **Ensure that GPU and RAM is set up: will be needed for training purpose**

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jul 17 14:49:52 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-32GB            Off| 00000000:AF:00.0 Off |                    0 |
# | N/A   54C    P0              262W / 300W|   7043MiB / 32768MiB |     71%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     25192      C   .../van-speech-nlp/condaENV/bin/python     7040MiB |
# +---------------------------------------------------------------------------------------+

# %%
# ensure enough memory present so that training does not stop
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 201.2 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ### **Install the libraries**

# %%
# Install required libraries
# !pip install datasets
# !pip install transformers==4.28.0
# !pip install accelerate
# !pip install jiwer
# !pip install huggingface_hub
# Out:
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# Requirement already satisfied: datasets in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (2.12.0)
# Requirement already satisfied: numpy>=1.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (1.24.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (12.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (0.15.1)
# Requirement already satisfied: packaging in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (23.1)
# Requirement already satisfied: responses<0.19 in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (from datasets) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: six in /home/chakraborti.m/.local/lib/python3.8/site-packages (from responses<0.19->datasets) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from pandas->datasets) (2023.3)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# Requirement already satisfied: transformers==4.28.0 in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (4.28.0)
# Requirement already satisfied: filelock in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (2023.6.3)
# Requirement already satisfied: requests in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from transformers==4.28.0) (4.65.0)
# Requirement already satisfied: fsspec in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests->transformers==4.28.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests->transformers==4.28.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (from requests->transformers==4.28.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests->transformers==4.28.0) (2023.5.7)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# Requirement already satisfied: accelerate in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from accelerate) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /home/chakraborti.m/.local/lib/python3.8/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /home/chakraborti.m/.local/lib/python3.8/site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (from accelerate) (1.12.1)
# Requirement already satisfied: typing-extensions in /home/chakraborti.m/.local/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (4.6.3)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# Requirement already satisfied: jiwer in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from jiwer) (8.1.3)
# Requirement already satisfied: rapidfuzz==2.13.7 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from jiwer) (2.13.7)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# Requirement already satisfied: huggingface_hub in /home/chakraborti.m/.local/lib/python3.8/site-packages (0.15.1)
# Requirement already satisfied: filelock in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /work/van-speech-nlp/condaENV/lib/python3.8/site-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chakraborti.m/.local/lib/python3.8/site-packages (from requests->huggingface_hub) (2023.5.7)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/chakraborti.m/.local/lib/python3.8/site-packages)

# %% [markdown]
# ### **Import libraries**

# %%
# Import libraries
import torch
from transformers import BartTokenizerFast, BartForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from jiwer import wer
from huggingface_hub import notebook_login

# %%
# Load the dataset from the JSON files
dataset = load_dataset('json', data_files={'train': '/work/van-speech-nlp/TORGO experiments/spelling correction/data preparation/language model experiments/json files/F01_other_speakers_LM.json',
                                           'test': '/work/van-speech-nlp/TORGO experiments/spelling correction/data preparation/language model experiments/json files/speaker_F01_LM.json'})
# Out:
# Found cached dataset json (/home/chakraborti.m/.cache/huggingface/datasets/json/default-834bbb932995c235/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['actual', 'prediction', 'speaker', 'path'],
#         num_rows: 5212
#     })
#     test: Dataset({
#         features: ['actual', 'prediction', 'speaker', 'path'],
#         num_rows: 215
#     })
# })

# %%
print(dataset['train'][:5])
print(dataset['test'][:5])
# Out:
# {'actual': ['beta ', 'stubble ', 'stubble ', 'trace ', 'goat '], 'prediction': ['beta', 'stubble', 'stubble', 'trace', 'goat'], 'speaker': ['F03', 'F03', 'F03', 'F03', 'F03'], 'path': ['/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F03/Session1/wav_arrayMic/0005.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F03/Session1/wav_arrayMic/0006.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F03/Session1/wav_arrayMic/0007.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F03/Session1/wav_arrayMic/0008.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F03/Session1/wav_arrayMic/0009.wav']}
# {'actual': ['stick ', 'except in the winter when the ooze or snow or ice prevents ', 'pat ', 'up ', 'meat '], 'prediction': ['snick', 'ealsein the winu we wol  orice pl', 'pat', 'up', 'nit'], 'speaker': ['F01', 'F01', 'F01', 'F01', 'F01'], 'path': ['/work/van-speech-nlp/TORGO experiments/dataset/Torgo/F01/Session1/wav_arrayMic/0006.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F01/Session1/wav_arrayMic/0008.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F01/Session1/wav_arrayMic/0009.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F01/Session1/wav_arrayMic/0010.wav', '/work/van-speech-nlp/TORGO experiments/dataset//Torgo/F01/Session1/wav_arrayMic/0012.wav']}

# %%
# Define the max_length for padding and truncation
max_length = 512

# %% [markdown]
# The preprocessing function serves to prepare the data for training or evaluation. It uses a tokenizer to tokenize the inputs and labels, formats the inputs by adding a source language identifier, encodes the tokenized inputs and labels, and creates a dictionary of model inputs. The function ensures that the data is properly tokenized, formatted, and encoded according to the model's requirements. It helps maintain consistency and compatibility between the input data and the model during training or evaluation.

# %%
# Initialize the tokenizer
tokenizer = BartTokenizerFast.from_pretrained('facebook/bart-base')

# Tokenize the data
# The preprocess_function function is defined to preprocess the data by tokenizing the inputs and labels
def preprocess_function(examples):
    inputs = [f'{source_lang}: {text}' for text in examples[source_lang]]
    targets = examples[target_lang]
    encoding = tokenizer(inputs, padding=True, truncation=True, return_tensors='pt', max_length=max_length)
    model_inputs = {
        'input_ids': encoding['input_ids'].squeeze(),
        'attention_mask': encoding['attention_mask'].squeeze(),
        'labels': tokenizer(targets, padding=True, truncation=True, return_tensors='pt')['input_ids'].squeeze()
    }
    return model_inputs

# %% [markdown]
# ### **Evaluate and Test the model**

# %%
# Load the trained model from Hugging Face
model = BartForConditionalGeneration.from_pretrained("monideep2255/spell_correction_F01_LM")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/558M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/292 [00:00<?, ?B/s]

# %%
# Move the model to the GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
#model.eval()
# Out:
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(50265, 768, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=50265, bias=False)
# )

# %%
# Test the model on speaker dataset
test_dataset = dataset['test'].filter(lambda example: example['speaker'] == 'F01')
print(len(test_dataset))
# Out:
# Filter:   0%|          | 0/215 [00:00<?, ? examples/s]
# 215

# %%
print(test_dataset)
# Out:
# Dataset({
#     features: ['actual', 'prediction', 'speaker', 'path'],
#     num_rows: 215
# })

# %%
# Inspect column names
column_names = test_dataset.column_names
print("Column names:", column_names)

# Inspect column data types
for column in column_names:
    column_data = test_dataset[column]
    data_type = type(column_data[0]) if len(column_data) > 0 else "Unknown"
    print(f"Column name: {column}, Data type: {data_type}")
# Out:
# Column names: ['actual', 'prediction', 'speaker', 'path']
# Column name: actual, Data type: <class 'str'>
# Column name: prediction, Data type: <class 'str'>
# Column name: speaker, Data type: <class 'str'>
# Column name: path, Data type: <class 'str'>

# %%
# verification
# Test the model on speaker dataset
verify_test_dataset = dataset['test']
print(len(verify_test_dataset))
print((verify_test_dataset))
# Out:
# 215
# Dataset({
#     features: ['actual', 'prediction', 'speaker', 'path'],
#     num_rows: 215
# })

# %%
# Define the source and target language columns
source_lang = 'prediction'
target_lang = 'actual'

# %%
test_data = test_dataset.map(preprocess_function, batched=True, batch_size=len(test_dataset))
model.eval()
# Out:
# Map:   0%|          | 0/215 [00:00<?, ? examples/s]
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(50265, 768, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=50265, bias=False)
# )

# %% [markdown]
# In the following code, we iterate over each example in the test_dataset and perform the following steps:
#
# - Concatenate the speaker ID and prediction to form the input text.
# - Tokenize the input text using the tokenizer.
# - Generate the output sequence using the trained model.
# - Decode the output sequence to obtain the predicted sentence.
# - Append the actual reference and the predicted sentence to the references and predictions lists, respectively.

# %%
predictions = []
references = []
inputs = []
for example in test_dataset:
    # This creates an input text by combining the values of the 'speaker' and 'prediction' fields from the current example.
    # It assumes that the example is a dictionary-like object with keys 'speaker' and 'prediction'.
    input_text = f"{example['speaker']}: {example['prediction']}"

    # This creates a context where no gradients are computed, which can improve efficiency during inference.
    with torch.no_grad():

        # This tokenizes the input_text using the tokenizer and converts it into input IDs as a PyTorch tensor.
        input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

        # The generate method generates the output sequence based on the provided input.
        outputs = model.generate(input_ids=input_ids, max_length=max_length)

    predicted_sentence = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    inputs.append(example['prediction'])
    references.append(example['actual'])
    predictions.append(predicted_sentence)

# %%
# Verify that the number of predictions and references are the same
if len(predictions) == len(references):
    print("Number of predictions and references are the same.")
else:
    print("Mismatch in the number of predictions and references.")
# Out:
# Number of predictions and references are the same.

# %%
# Print the number of predictions and references
print("Number of predictions:", len(predictions))
print("Number of references:", len(references))
print("Number of inputs:", len(inputs))
# print the length of the dataset
print("Number of rows in dataset:", len(test_dataset))
# Out:
# Number of predictions: 215
# Number of references: 215
# Number of inputs: 215
# Number of rows in dataset: 215

# %%
# Verify the first 10 predictions and references side by side
for i in range(10):
    print("Reference:", references[i])
    print("Prediction:", predictions[i])
    print("Inputs:", inputs[i])
    print("---")
# Out:
# Reference: stick
# Prediction: snoop
# Inputs: snick
# ---
# Reference: except in the winter when the ooze or snow or ice prevents
# Prediction: in the winter we play skillfully and with zest upon our small organ
# Inputs: ealsein the winu we wol  orice pl
# ---
# Reference: pat
# Prediction: pat
# Inputs: pat
# ---
# Reference: up
# Prediction: up
# Inputs: up
# ---
# Reference: meat
# Prediction: nit
# Inputs: nit
# ---
# Reference: know
# Prediction: know
# Inputs: now
# ---
# Reference: he slowly takes a short walk in the open air each day
# Prediction: giving those who observe him a pronounced feeling of the utmost respect
# Inputs: e loly caks a f walt muopeing ar eack day
# ---
# Reference: air
# Prediction: hem
# Inputs: hem
# ---
# Reference: swarm
# Prediction: floor
# Inputs: floor
# ---
# Reference: double
# Prediction: double
# Inputs: double
# ---

# %%
import csv

# Specify the CSV file path
csv_file = '/work/van-speech-nlp/TORGO experiments/spelling correction/SC_train and evaluate/language model/results-csv/F01.csv'

# Verify and write all predictions and references to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the header
    writer.writerow(['Reference', 'Input sentence', 'Prediction'])

    # Write the predictions and references
    for i in range(len(references)):
        reference = references[i]
        prediction = predictions[i]
        input_sentence = inputs[i]
        # Write the row to the CSV file
        writer.writerow([reference, input_sentence, prediction])

print("Results saved to", csv_file)
# Out:
# Results saved to /work/van-speech-nlp/TORGO experiments/spelling correction/SC_train and evaluate/language model/results-csv/F01.csv

# %% [markdown]
# ### **WER calculation for test speaker**

# %% [markdown]
# The code snippet calculates the Word Error Rate (WER) for the test speaker. It iterates over the predictions and references, comparing each prediction to its corresponding reference.

# %%
# calculate WER

from jiwer import wer

wer_value = wer(predictions, references)
wer_percentage = wer_value * 100

print(f"WER: {wer_percentage:.2f}%")
# Out:
# WER: 31.23%
